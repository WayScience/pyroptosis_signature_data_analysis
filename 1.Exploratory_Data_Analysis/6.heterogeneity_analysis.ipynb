# %% [markdown]
# # This notebook looks into the cell heterogeneity in the control treatments

# %%
import itertools
import pathlib
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
import toml
import umap
from sklearn.cluster import KMeans
# Out:
# /projects/mlippincott@xsede.org/software/anaconda/envs/Interstellar/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /projects/mlippincott@xsede.org/software/anaconda/envs/Interstellar/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /projects/mlippincott@xsede.org/software/anaconda/envs/Interstellar/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /projects/mlippincott@xsede.org/software/anaconda/envs/Interstellar/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
# Parameters
cell_type = "PBMC"

# %%
# read in toml file

# set up the path
toml_path = pathlib.Path("./utils/params.toml")
# read in the toml file
params = toml.load(toml_path)
list_of_treatments = params["list_of_treatments"]["treatments"]
print(len(list_of_treatments))
print(list_of_treatments)
# Out:
# 15
# ['DMSO_0.100_%_DMSO_0.025_%', 'Thapsigargin_1.000_uM_DMSO_0.025_%', 'Thapsigargin_10.000_uM_DMSO_0.025_%', 'H2O2_100.000_uM_DMSO_0.025_%', 'H2O2_100.000_nM_DMSO_0.025_%', 'Flagellin_0.100_ug_per_ml_DMSO_0.025_%', 'Flagellin_1.000_ug_per_ml_DMSO_0.025_%', 'LPS_0.010_ug_per_ml_DMSO_0.025_%', 'LPS_0.100_ug_per_ml_DMSO_0.025_%', 'LPS_1.000_ug_per_ml_DMSO_0.025_%', 'LPS_10.000_ug_per_ml_DMSO_0.025_%', 'LPS_100.000_ug_per_ml_DMSO_0.025_%', 'LPS_Nigericin_1.000_ug_per_ml_1.000_uM_DMSO_0.025_%', 'LPS_Nigericin_1.000_ug_per_ml_3.000_uM_DMSO_0.025_%', 'LPS_Nigericin_1.000_ug_per_ml_10.000_uM_DMSO_0.025_%']

# %%
# Set path to parquet file
path = pathlib.Path(f"../data/{cell_type}_preprocessed_sc_norm.parquet")
# Read in parquet file
df = pq.read_table(path).to_pandas()
df
# Out:
#         Metadata_cell_type Metadata_Well  Metadata_number_of_singlecells  \
# 0                     PBMC           B02                           34618
# 1                     PBMC           B02                           34618
# 2                     PBMC           B02                           34618
# 3                     PBMC           B02                           34618
# 4                     PBMC           B02                           34618
# ...                    ...           ...                             ...
# 5598677               PBMC           O12                           29822
# 5598678               PBMC           O12                           29822
# 5598679               PBMC           O12                           29822
# 5598680               PBMC           O12                           29822
# 5598681               PBMC           O12                           29822
#
#          Metadata_incubation inducer (h) Metadata_inhibitor  \
# 0                                      6               DMSO
# 1                                      6               DMSO
# 2                                      6               DMSO
# 3                                      6               DMSO
# 4                                      6               DMSO
# ...                                  ...                ...
# 5598677                                6               DMSO
# 5598678                                6               DMSO
# 5598679                                6               DMSO
# 5598680                                6               DMSO
# 5598681                                6               DMSO
#
#         Metadata_inhibitor_concentration  \
# 0                                  0.025
# 1                                  0.025
# 2                                  0.025
# 3                                  0.025
# 4                                  0.025
# ...                                  ...
# 5598677                            1.000
# 5598678                            1.000
# 5598679                            1.000
# 5598680                            1.000
# 5598681                            1.000
#
#         Metadata_inhibitor_concentration_unit Metadata_inducer1  \
# 0                                           %               LPS
# 1                                           %               LPS
# 2                                           %               LPS
# 3                                           %               LPS
# 4                                           %               LPS
# ...                                       ...               ...
# 5598677                                     %              DMSO
# 5598678                                     %              DMSO
# 5598679                                     %              DMSO
# 5598680                                     %              DMSO
# 5598681                                     %              DMSO
#
#         Metadata_inducer1_concentration Metadata_inducer1_concentration_unit  \
# 0                                 0.010                            µg_per_ml
# 1                                 0.010                            µg_per_ml
# 2                                 0.010                            µg_per_ml
# 3                                 0.010                            µg_per_ml
# 4                                 0.010                            µg_per_ml
# ...                                 ...                                  ...
# 5598677                           0.100                                    %
# 5598678                           0.100                                    %
# 5598679                           0.100                                    %
# 5598680                           0.100                                    %
# 5598681                           0.100                                    %
#
#          ... Nuclei_Texture_SumEntropy_CorrPM_3_01_256  \
# 0        ...                                  0.108250
# 1        ...                                 -0.929131
# 2        ...                                 -1.227278
# 3        ...                                  2.153910
# 4        ...                                 -0.557309
# ...      ...                                       ...
# 5598677  ...                                 -0.376617
# 5598678  ...                                 -0.120779
# 5598679  ...                                 -0.291924
# 5598680  ...                                  0.473149
# 5598681  ...                                 -0.091946
#
#         Nuclei_Texture_SumVariance_CorrPM_3_01_256  \
# 0                                        -0.068544
# 1                                        -0.158906
# 2                                        -0.163521
# 3                                         0.586555
# 4                                        -0.148980
# ...                                            ...
# 5598677                                  -0.030944
# 5598678                                  -0.114803
# 5598679                                  -0.141514
# 5598680                                  -0.077816
# 5598681                                  -0.125663
#
#         Nuclei_Texture_Variance_CorrER_3_00_256  \
# 0                                     -0.205295
# 1                                     -0.198572
# 2                                     -0.165140
# 3                                      0.258023
# 4                                     -0.122860
# ...                                         ...
# 5598677                               -0.203394
# 5598678                               -0.204566
# 5598679                               -0.188326
# 5598680                               -0.166199
# 5598681                               -0.129558
#
#          Nuclei_Texture_Variance_CorrGasdermin_3_00_256 Metadata_Treatment  \
# 0                                             -0.197257                LPS
# 1                                             -0.185623                LPS
# 2                                             -0.174762                LPS
# 3                                              0.218118                LPS
# 4                                             -0.110851                LPS
# ...                                                 ...                ...
# 5598677                                       -0.206115               DMSO
# 5598678                                       -0.186447               DMSO
# 5598679                                       -0.173827               DMSO
# 5598680                                       -0.156101               DMSO
# 5598681                                       -0.120257               DMSO
#
#            Metadata_Dose  oneb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 0        0.010_µg_per_ml             LPS_0.010_ug_per_ml_DMSO_0.025_%
# 1        0.010_µg_per_ml             LPS_0.010_ug_per_ml_DMSO_0.025_%
# 2        0.010_µg_per_ml             LPS_0.010_ug_per_ml_DMSO_0.025_%
# 3        0.010_µg_per_ml             LPS_0.010_ug_per_ml_DMSO_0.025_%
# 4        0.010_µg_per_ml             LPS_0.010_ug_per_ml_DMSO_0.025_%
# ...                  ...                                          ...
# 5598677          0.100_%                    DMSO_0.100_%_DMSO_1.000_%
# 5598678          0.100_%                    DMSO_0.100_%_DMSO_1.000_%
# 5598679          0.100_%                    DMSO_0.100_%_DMSO_1.000_%
# 5598680          0.100_%                    DMSO_0.100_%_DMSO_1.000_%
# 5598681          0.100_%                    DMSO_0.100_%_DMSO_1.000_%
#
#          twob_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 0                    LPS_DMSO_0.025__0.010_µg_per_ml
# 1                    LPS_DMSO_0.025__0.010_µg_per_ml
# 2                    LPS_DMSO_0.025__0.010_µg_per_ml
# 3                    LPS_DMSO_0.025__0.010_µg_per_ml
# 4                    LPS_DMSO_0.025__0.010_µg_per_ml
# ...                                              ...
# 5598677                     DMSO_DMSO_1.000__0.100_%
# 5598678                     DMSO_DMSO_1.000__0.100_%
# 5598679                     DMSO_DMSO_1.000__0.100_%
# 5598680                     DMSO_DMSO_1.000__0.100_%
# 5598681                     DMSO_DMSO_1.000__0.100_%
#
#          threeb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 0           LPS__0.010_µg_per_ml__µg_per_ml_DMSO_0.025
# 1           LPS__0.010_µg_per_ml__µg_per_ml_DMSO_0.025
# 2           LPS__0.010_µg_per_ml__µg_per_ml_DMSO_0.025
# 3           LPS__0.010_µg_per_ml__µg_per_ml_DMSO_0.025
# 4           LPS__0.010_µg_per_ml__µg_per_ml_DMSO_0.025
# ...                                                ...
# 5598677                    DMSO__0.100_%__%_DMSO_1.000
# 5598678                    DMSO__0.100_%__%_DMSO_1.000
# 5598679                    DMSO__0.100_%__%_DMSO_1.000
# 5598680                    DMSO__0.100_%__%_DMSO_1.000
# 5598681                    DMSO__0.100_%__%_DMSO_1.000
#
#          fourb_Metadata_Treatment_Dose_Inhibitor_Dose
# 0         LPS__0.010_µg_per_ml__µg_per_ml_DMSO__0.025
# 1         LPS__0.010_µg_per_ml__µg_per_ml_DMSO__0.025
# 2         LPS__0.010_µg_per_ml__µg_per_ml_DMSO__0.025
# 3         LPS__0.010_µg_per_ml__µg_per_ml_DMSO__0.025
# 4         LPS__0.010_µg_per_ml__µg_per_ml_DMSO__0.025
# ...                                               ...
# 5598677                  DMSO__0.100_%__%_DMSO__1.000
# 5598678                  DMSO__0.100_%__%_DMSO__1.000
# 5598679                  DMSO__0.100_%__%_DMSO__1.000
# 5598680                  DMSO__0.100_%__%_DMSO__1.000
# 5598681                  DMSO__0.100_%__%_DMSO__1.000
#
# [5598682 rows x 1270 columns]

# %%
df["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"]
# subset the df for the control
df = df[
    df["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"] == "DMSO_0.100_%_DMSO_0.025_%"
]
df
# Out:
#         Metadata_cell_type Metadata_Well  Metadata_number_of_singlecells  \
# 315708                PBMC           B06                           25314
# 315709                PBMC           B06                           25314
# 315710                PBMC           B06                           25314
# 315711                PBMC           B06                           25314
# 315712                PBMC           B06                           25314
# ...                    ...           ...                             ...
# 3555691               PBMC           J07                           29315
# 3555692               PBMC           J07                           29315
# 3555693               PBMC           J07                           29315
# 3555694               PBMC           J07                           29315
# 3555695               PBMC           J07                           29315
#
#          Metadata_incubation inducer (h) Metadata_inhibitor  \
# 315708                                 6               DMSO
# 315709                                 6               DMSO
# 315710                                 6               DMSO
# 315711                                 6               DMSO
# 315712                                 6               DMSO
# ...                                  ...                ...
# 3555691                                6               DMSO
# 3555692                                6               DMSO
# 3555693                                6               DMSO
# 3555694                                6               DMSO
# 3555695                                6               DMSO
#
#         Metadata_inhibitor_concentration  \
# 315708                             0.025
# 315709                             0.025
# 315710                             0.025
# 315711                             0.025
# 315712                             0.025
# ...                                  ...
# 3555691                            0.025
# 3555692                            0.025
# 3555693                            0.025
# 3555694                            0.025
# 3555695                            0.025
#
#         Metadata_inhibitor_concentration_unit Metadata_inducer1  \
# 315708                                      %              DMSO
# 315709                                      %              DMSO
# 315710                                      %              DMSO
# 315711                                      %              DMSO
# 315712                                      %              DMSO
# ...                                       ...               ...
# 3555691                                     %              DMSO
# 3555692                                     %              DMSO
# 3555693                                     %              DMSO
# 3555694                                     %              DMSO
# 3555695                                     %              DMSO
#
#         Metadata_inducer1_concentration Metadata_inducer1_concentration_unit  \
# 315708                            0.100                                    %
# 315709                            0.100                                    %
# 315710                            0.100                                    %
# 315711                            0.100                                    %
# 315712                            0.100                                    %
# ...                                 ...                                  ...
# 3555691                           0.100                                    %
# 3555692                           0.100                                    %
# 3555693                           0.100                                    %
# 3555694                           0.100                                    %
# 3555695                           0.100                                    %
#
#          ... Nuclei_Texture_SumEntropy_CorrPM_3_01_256  \
# 315708   ...                                 -0.299580
# 315709   ...                                 -0.906742
# 315710   ...                                 -0.392149
# 315711   ...                                 -1.128252
# 315712   ...                                 -0.815351
# ...      ...                                       ...
# 3555691  ...                                  0.081205
# 3555692  ...                                  1.855869
# 3555693  ...                                 -0.060551
# 3555694  ...                                  1.742261
# 3555695  ...                                 -0.398271
#
#         Nuclei_Texture_SumVariance_CorrPM_3_01_256  \
# 315708                                   -0.137086
# 315709                                   -0.156287
# 315710                                   -0.146205
# 315711                                   -0.162255
# 315712                                   -0.142273
# ...                                            ...
# 3555691                                  -0.116326
# 3555692                                   0.493227
# 3555693                                  -0.116721
# 3555694                                   0.675294
# 3555695                                  -0.143137
#
#         Nuclei_Texture_Variance_CorrER_3_00_256  \
# 315708                                -0.111979
# 315709                                -0.171005
# 315710                                -0.169050
# 315711                                -0.170928
# 315712                                -0.192711
# ...                                         ...
# 3555691                               -0.194867
# 3555692                               -0.105125
# 3555693                               -0.198838
# 3555694                                0.041459
# 3555695                               -0.192437
#
#          Nuclei_Texture_Variance_CorrGasdermin_3_00_256 Metadata_Treatment  \
# 315708                                        -0.115607               DMSO
# 315709                                        -0.161728               DMSO
# 315710                                        -0.166613               DMSO
# 315711                                        -0.155808               DMSO
# 315712                                        -0.194270               DMSO
# ...                                                 ...                ...
# 3555691                                       -0.181788               DMSO
# 3555692                                       -0.068579               DMSO
# 3555693                                       -0.181509               DMSO
# 3555694                                        0.213104               DMSO
# 3555695                                       -0.187718               DMSO
#
#          Metadata_Dose  oneb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 315708         0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 315709         0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 315710         0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 315711         0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 315712         0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# ...                ...                                          ...
# 3555691        0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 3555692        0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 3555693        0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 3555694        0.100_%                    DMSO_0.100_%_DMSO_0.025_%
# 3555695        0.100_%                    DMSO_0.100_%_DMSO_0.025_%
#
#          twob_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 315708                      DMSO_DMSO_0.025__0.100_%
# 315709                      DMSO_DMSO_0.025__0.100_%
# 315710                      DMSO_DMSO_0.025__0.100_%
# 315711                      DMSO_DMSO_0.025__0.100_%
# 315712                      DMSO_DMSO_0.025__0.100_%
# ...                                              ...
# 3555691                     DMSO_DMSO_0.025__0.100_%
# 3555692                     DMSO_DMSO_0.025__0.100_%
# 3555693                     DMSO_DMSO_0.025__0.100_%
# 3555694                     DMSO_DMSO_0.025__0.100_%
# 3555695                     DMSO_DMSO_0.025__0.100_%
#
#          threeb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 315708                     DMSO__0.100_%__%_DMSO_0.025
# 315709                     DMSO__0.100_%__%_DMSO_0.025
# 315710                     DMSO__0.100_%__%_DMSO_0.025
# 315711                     DMSO__0.100_%__%_DMSO_0.025
# 315712                     DMSO__0.100_%__%_DMSO_0.025
# ...                                                ...
# 3555691                    DMSO__0.100_%__%_DMSO_0.025
# 3555692                    DMSO__0.100_%__%_DMSO_0.025
# 3555693                    DMSO__0.100_%__%_DMSO_0.025
# 3555694                    DMSO__0.100_%__%_DMSO_0.025
# 3555695                    DMSO__0.100_%__%_DMSO_0.025
#
#          fourb_Metadata_Treatment_Dose_Inhibitor_Dose
# 315708                   DMSO__0.100_%__%_DMSO__0.025
# 315709                   DMSO__0.100_%__%_DMSO__0.025
# 315710                   DMSO__0.100_%__%_DMSO__0.025
# 315711                   DMSO__0.100_%__%_DMSO__0.025
# 315712                   DMSO__0.100_%__%_DMSO__0.025
# ...                                               ...
# 3555691                  DMSO__0.100_%__%_DMSO__0.025
# 3555692                  DMSO__0.100_%__%_DMSO__0.025
# 3555693                  DMSO__0.100_%__%_DMSO__0.025
# 3555694                  DMSO__0.100_%__%_DMSO__0.025
# 3555695                  DMSO__0.100_%__%_DMSO__0.025
#
# [215130 rows x 1270 columns]

# %%
# Code snippet for metadata extraction by Jenna Tomkinson
df_metadata = list(df.columns[df.columns.str.contains("Metadata")])

# define which columns are data and which are descriptive
df_descriptive = df[df_metadata]
df_values = df.drop(columns=df_metadata)

# %%
# set umap parameters
umap_params = umap.UMAP(
    n_components=2,
    spread=1.1,
    random_state=0,
    n_neighbors=6,
    min_dist=0.8,
    metric="cosine",
)

# %%
# fit and transform data for umap
proj_2d = umap_params.fit_transform(df_values)

# add umap coordinates to dataframe of metadata and raw data
df_values["umap_1"] = proj_2d[:, 0]
df_values["umap_2"] = proj_2d[:, 1]

# %%
df_values["fourb_Metadata_Treatment_Dose_Inhibitor_Dose"] = df_descriptive[
    "fourb_Metadata_Treatment_Dose_Inhibitor_Dose"
]
df_values["Metadata_Well"] = df_descriptive["Metadata_Well"]

# %%
# Figure Showing UMAP of Clusters vs Treatment
sns.scatterplot(
    data=df_values,
    x="umap_1",
    y="umap_2",
    hue="Metadata_Well",
    legend="full",
    # make points smaller,
    s=10,
    alpha=0.3,
)
# add contour lines to the plot

plt.title(f"Visualized {cell_type} on umap")
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", borderaxespad=0)

# if path does not exist create it
plt.savefig(
    f"Figures/umap_plate2/cell_heterogeneity_{cell_type}_umap.png", bbox_inches="tight"
)
