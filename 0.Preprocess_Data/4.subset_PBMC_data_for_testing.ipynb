# %%
import pathlib

import numpy as np
import pandas as pd
import papermill as pm
import pyarrow as pa
import pyarrow.parquet as pq

# %%
# Parameters
celltype = "PBMC"
CONTROL_NAME = "DMSO_0.100_DMSO_0.025"
TREATMENT_NAME = "LPS_100.000_DMSO_0.025"

# %%
# Define inputs
feature_file = pathlib.Path("../data/PBMC_preprocessed_sc_norm.parquet")
df = pd.read_parquet(feature_file).to_pandas()
output_dir = pathlib.Path(
    f"../data/PBMC_subset_sc_norm_{CONTROL_NAME}_{TREATMENT_NAME}.parquet"
)

# %%
# filter the oneb_Metadata_Treatment_Dose_Inhibitor_Dose column to only include the treatment and control via loc
df = df.loc[
    df["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"].isin(
        [TREATMENT_NAME, CONTROL_NAME]
    )
]

# %%
df.to_parquet(output_dir)
# Out:
#        Metadata_cell_type Metadata_Well  Metadata_number_of_singlecells  \
# 27315             SH-SY5Y           B14                            4281
# 27316             SH-SY5Y           B14                            4281
# 27317             SH-SY5Y           B14                            4281
# 27318             SH-SY5Y           B14                            4281
# 27319             SH-SY5Y           B14                            4281
# ...                   ...           ...                             ...
# 528609            SH-SY5Y           J21                            4126
# 528610            SH-SY5Y           J21                            4126
# 528611            SH-SY5Y           J21                            4126
# 528612            SH-SY5Y           J21                            4126
# 528613            SH-SY5Y           J21                            4126
#
#         Metadata_incubation inducer (h) Metadata_inhibitor  \
# 27315                                 6               DMSO
# 27316                                 6               DMSO
# 27317                                 6               DMSO
# 27318                                 6               DMSO
# 27319                                 6               DMSO
# ...                                 ...                ...
# 528609                                6               DMSO
# 528610                                6               DMSO
# 528611                                6               DMSO
# 528612                                6               DMSO
# 528613                                6               DMSO
#
#         Metadata_inhibitor_concentration  \
# 27315                              0.025
# 27316                              0.025
# 27317                              0.025
# 27318                              0.025
# 27319                              0.025
# ...                                  ...
# 528609                             0.025
# 528610                             0.025
# 528611                             0.025
# 528612                             0.025
# 528613                             0.025
#
#        Metadata_inhibitor_concentration_unit Metadata_inducer1  \
# 27315                                      %              DMSO
# 27316                                      %              DMSO
# 27317                                      %              DMSO
# 27318                                      %              DMSO
# 27319                                      %              DMSO
# ...                                      ...               ...
# 528609                                     %               LPS
# 528610                                     %               LPS
# 528611                                     %               LPS
# 528612                                     %               LPS
# 528613                                     %               LPS
#
#         Metadata_inducer1_concentration Metadata_inducer1_concentration_unit  \
# 27315                               0.1                                    %
# 27316                               0.1                                    %
# 27317                               0.1                                    %
# 27318                               0.1                                    %
# 27319                               0.1                                    %
# ...                                 ...                                  ...
# 528609                            100.0                            µg_per_ml
# 528610                            100.0                            µg_per_ml
# 528611                            100.0                            µg_per_ml
# 528612                            100.0                            µg_per_ml
# 528613                            100.0                            µg_per_ml
#
#         ... Nuclei_Texture_SumEntropy_CorrPM_3_01_256  \
# 27315   ...                                  0.410355
# 27316   ...                                 -0.611225
# 27317   ...                                 -0.697017
# 27318   ...                                  0.080572
# 27319   ...                                 -0.560388
# ...     ...                                       ...
# 528609  ...                                 -0.145428
# 528610  ...                                  0.351248
# 528611  ...                                  0.882730
# 528612  ...                                  1.429805
# 528613  ...                                 -0.090842
#
#         Nuclei_Texture_SumVariance_CorrGasdermin_3_01_256  \
# 27315                                           -0.061888
# 27316                                           -0.067765
# 27317                                           -0.043602
# 27318                                           -0.067427
# 27319                                           -0.061698
# ...                                                   ...
# 528609                                          -0.066186
# 528610                                          -0.068190
# 528611                                          -0.066998
# 528612                                           0.017140
# 528613                                          -0.070266
#
#        Nuclei_Texture_SumVariance_CorrMito_3_03_256  \
# 27315                                     -0.124722
# 27316                                     -0.105689
# 27317                                      0.227231
# 27318                                      0.001902
# 27319                                     -0.102657
# ...                                             ...
# 528609                                     0.039912
# 528610                                    -0.101820
# 528611                                    -0.102031
# 528612                                     4.071859
# 528613                                     0.306194
#
#         Nuclei_Texture_SumVariance_CorrPM_3_03_256 Metadata_Treatment  \
# 27315                                    -0.020174               DMSO
# 27316                                    -0.058699               DMSO
# 27317                                    -0.059998               DMSO
# 27318                                    -0.045309               DMSO
# 27319                                    -0.039802               DMSO
# ...                                            ...                ...
# 528609                                   -0.049027                LPS
# 528610                                   -0.039064                LPS
# 528611                                    0.003438                LPS
# 528612                                    0.030545                LPS
# 528613                                   -0.044153                LPS
#
#         Metadata_Dose  oneb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 27315           0.100                        DMSO_0.100_DMSO_0.025
# 27316           0.100                        DMSO_0.100_DMSO_0.025
# 27317           0.100                        DMSO_0.100_DMSO_0.025
# 27318           0.100                        DMSO_0.100_DMSO_0.025
# 27319           0.100                        DMSO_0.100_DMSO_0.025
# ...               ...                                          ...
# 528609        100.000                       LPS_100.000_DMSO_0.025
# 528610        100.000                       LPS_100.000_DMSO_0.025
# 528611        100.000                       LPS_100.000_DMSO_0.025
# 528612        100.000                       LPS_100.000_DMSO_0.025
# 528613        100.000                       LPS_100.000_DMSO_0.025
#
#         twob_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 27315                        DMSO_DMSO_0.025__0.100
# 27316                        DMSO_DMSO_0.025__0.100
# 27317                        DMSO_DMSO_0.025__0.100
# 27318                        DMSO_DMSO_0.025__0.100
# 27319                        DMSO_DMSO_0.025__0.100
# ...                                             ...
# 528609                      LPS_DMSO_0.025__100.000
# 528610                      LPS_DMSO_0.025__100.000
# 528611                      LPS_DMSO_0.025__100.000
# 528612                      LPS_DMSO_0.025__100.000
# 528613                      LPS_DMSO_0.025__100.000
#
#         threeb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 27315                         DMSO__0.100__DMSO_0.025
# 27316                         DMSO__0.100__DMSO_0.025
# 27317                         DMSO__0.100__DMSO_0.025
# 27318                         DMSO__0.100__DMSO_0.025
# 27319                         DMSO__0.100__DMSO_0.025
# ...                                               ...
# 528609                       LPS__100.000__DMSO_0.025
# 528610                       LPS__100.000__DMSO_0.025
# 528611                       LPS__100.000__DMSO_0.025
# 528612                       LPS__100.000__DMSO_0.025
# 528613                       LPS__100.000__DMSO_0.025
#
#         fourb_Metadata_Treatment_Dose_Inhibitor_Dose
# 27315                       DMSO__0.100__DMSO__0.025
# 27316                       DMSO__0.100__DMSO__0.025
# 27317                       DMSO__0.100__DMSO__0.025
# 27318                       DMSO__0.100__DMSO__0.025
# 27319                       DMSO__0.100__DMSO__0.025
# ...                                              ...
# 528609                     LPS__100.000__DMSO__0.025
# 528610                     LPS__100.000__DMSO__0.025
# 528611                     LPS__100.000__DMSO__0.025
# 528612                     LPS__100.000__DMSO__0.025
# 528613                     LPS__100.000__DMSO__0.025
#
# [51630 rows x 1276 columns]
