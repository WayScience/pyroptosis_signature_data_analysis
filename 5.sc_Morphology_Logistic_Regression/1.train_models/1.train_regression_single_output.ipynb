# %%
import ast
import itertools
import pathlib
import sys
import warnings

import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import toml
from joblib import dump
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import ElasticNetCV, LogisticRegression, MultiTaskElasticNetCV

# import mse
from sklearn.metrics import mean_squared_error, r2_score

# import RepeatedKFold
from sklearn.model_selection import (
    GridSearchCV,
    RepeatedKFold,
    StratifiedKFold,
    train_test_split,
)
from sklearn.utils import parallel_backend, shuffle

# %%
# Parameters
cell_type = "PBMC"
aggregation = True
nomic = True
flag = True
control = "DMSO_0.100_DMSO_0.025"
treatment = "LPS_100.000_DMSO_0.025"

# %%
MODEL_TYPE = "regression"
if flag == False:
    # read in toml file and get parameters
    toml_path = pathlib.Path("single_class_config.toml")
    with open(toml_path, "r") as f:
        config = toml.load(f)
    control = config["logistic_regression_params"]["control"]
    treatment = config["logistic_regression_params"]["treatments"]
    aggregation = ast.literal_eval(config["logistic_regression_params"]["aggregation"])
    nomic = ast.literal_eval(config["logistic_regression_params"]["nomic"])
    cell_type = config["logistic_regression_params"]["cell_type"]

# %%
# load training data from indexes and features dataframe
# data_split_path = pathlib.Path(f"../0.split_data/indexes/data_split_indexes.tsv")
# data_path = pathlib.Path(f"../../data/{cell_type}_preprocessed_sc_norm.parquet")
data_path = pathlib.Path(
    "../../data/PBMC_subset_sc_norm_DMSO_0.100_DMSO_0.025_LPS_100.000_DMSO_0.025.parquet"
)

# dataframe with only the labeled data we want (exclude certain phenotypic classes)
data_df = pq.read_table(data_path).to_pandas()

# import nomic data
nomic_df_path = pathlib.Path(
    f"../../2.Nomic_nELISA_Analysis/Data/clean/Plate2/nELISA_plate_430420_{cell_type}_cleanup4correlation.csv"
)
df_nomic = pd.read_csv(nomic_df_path)

# clean up nomic data
df_nomic = df_nomic.drop(columns=[col for col in df_nomic.columns if "[pgML]" in col])
# drop first 25 columns (Metadata that is not needed)
# df_nomic = df_nomic.drop(columns=df_nomic.columns[3:25])
# df_nomic = df_nomic.drop(columns=df_nomic.columns[0:2])

# %%
print(df_nomic["Activin A [NSU]"].std())
print(df_nomic["Activin A [NSU]"].mean())
print(df_nomic["Activin A [NSU]"].max())
print(df_nomic["Activin A [NSU]"].min())
# min max scale nomic data (0-1) using sklearn
# Out:
# 0.27220830038007515
# 0.21036656278540763
# 1.0
# 0.0

# %%
if (aggregation == True) and (nomic == True):
    data_split_path = pathlib.Path(
        f"../0.split_data/indexes/{cell_type}/{MODEL_TYPE}/{control}_{treatment}/aggregated_sc_and_nomic_data_split_indexes.tsv"
    )
    data_split_indexes = pd.read_csv(data_split_path, sep="\t", index_col=0)
    # subset each column that contains metadata
    metadata = data_df.filter(regex="Metadata")
    data_df = data_df.drop(metadata.columns, axis=1)
    data_df = pd.concat([data_df, metadata["Metadata_Well"]], axis=1)
    # groupby well and take mean of each well
    data_df = data_df.groupby("Metadata_Well").mean()
    # drop duplicate rows in the metadata_well column
    metadata = metadata.drop_duplicates(subset=["Metadata_Well"])
    # get the metadata for each well
    data_df = pd.merge(
        data_df, metadata, left_on="Metadata_Well", right_on="Metadata_Well"
    )
    data_df = pd.merge(
        data_df,
        df_nomic,
        left_on=["Metadata_Well", "oneb_Metadata_Treatment_Dose_Inhibitor_Dose"],
        right_on=["Metadata_position_x", "oneb_Metadata_Treatment_Dose_Inhibitor_Dose"],
    )
    data_df = data_df.drop(columns=["Metadata_position_x"])
elif (aggregation == True) and (nomic == False):
    data_split_path = pathlib.Path(
        f"../0.split_data/indexes/{cell_type}/{MODEL_TYPE}/{control}_{treatment}/aggregated_sc_data_split_indexes.tsv"
    )
    data_split_indexes = pd.read_csv(data_split_path, sep="\t", index_col=0)
    # subset each column that contains metadata
    metadata = data_df.filter(regex="Metadata")
    data_df = data_df.drop(metadata.columns, axis=1)
    data_df = pd.concat([data_df, metadata["Metadata_Well"]], axis=1)
    # groupby well and take mean of each well
    data_df = data_df.groupby("Metadata_Well").mean()
    # drop duplicate rows in the metadata_well column
    metadata = metadata.drop_duplicates(subset=["Metadata_Well"])
    # get the metadata for each well
    data_df = pd.merge(
        data_df, metadata, left_on="Metadata_Well", right_on="Metadata_Well"
    )
elif (aggregation == False) and (nomic == True):
    data_split_path = pathlib.Path(
        f"../0.split_data/indexes/{cell_type}/{MODEL_TYPE}/{control}_{treatment}/sc_and_nomic_data_split_indexes.tsv"
    )
    data_split_indexes = pd.read_csv(data_split_path, sep="\t", index_col=0)
    data_df = pd.merge(
        data_df, df_nomic, left_on="Metadata_Well", right_on="Metadata_position_x"
    )
    data_df = data_df.drop(columns=["Metadata_position_x"])
elif aggregation == False and nomic == False:
    data_split_path = pathlib.Path(
        f"../0.split_data/indexes/{cell_type}/{MODEL_TYPE}/{control}_{treatment}/sc_split_indexes.tsv"
    )
    data_split_indexes = pd.read_csv(data_split_path, sep="\t", index_col=0)
else:
    print("Error")

# %%
# select tht indexes for the training and test set
train_indexes = data_split_indexes.loc[data_split_indexes["label"] == "train"]

# %%
# subset data_df by indexes in data_split_indexes
training_data = data_df.loc[train_indexes["labeled_data_index"]]

# %%
# get oneb_Metadata_Treatment_Dose_Inhibitor_Dose  =='DMSO_0.100_DMSO_0.025' and 'LPS_100.000_DMSO_0.025 and Thapsigargin_10.000_DMSO_0.025'
training_data = training_data[
    training_data["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"].isin(
        [control, treatment]
    )
]
training_data
# Out:
#    Metadata_Well  Cytoplasm_AreaShape_Compactness  \
# 0            B06                         0.022371
# 1            B07                        -0.071753
# 2            C06                         0.061913
# 4            I06                         0.048882
# 6            J02                        -0.004170
# 8            J06                        -0.012228
# 9            J07                        -0.000175
# 10           J08                        -0.048434
# 11           J09                        -0.001276
#
#     Cytoplasm_AreaShape_FormFactor  Cytoplasm_AreaShape_MajorAxisLength  \
# 0                        -0.022614                            -0.039573
# 1                         0.049418                            -0.080162
# 2                        -0.047412                             0.052250
# 4                        -0.014356                             0.110362
# 6                         0.009121                             0.015575
# 8                        -0.005155                            -0.048954
# 9                         0.007426                             0.030708
# 10                        0.044146                            -0.002124
# 11                       -0.002025                             0.041489
#
#     Cytoplasm_AreaShape_MinorAxisLength  Cytoplasm_AreaShape_Orientation  \
# 0                             -0.049300                        -0.013386
# 1                             -0.110935                         0.009102
# 2                              0.083849                         0.024151
# 4                              0.115949                        -0.005469
# 6                             -0.078282                         0.009186
# 8                             -0.032680                        -0.012399
# 9                              0.024561                        -0.001792
# 10                            -0.099024                        -0.014325
# 11                            -0.035258                        -0.000377
#
#     Cytoplasm_AreaShape_Zernike_0_0  Cytoplasm_AreaShape_Zernike_1_1  \
# 0                         -0.035579                        -0.026341
# 1                          0.018723                         0.007016
# 2                         -0.026974                        -0.013448
# 4                          0.024033                         0.043835
# 6                         -0.100801                        -0.090802
# 8                         -0.034741                        -0.046950
# 9                          0.018262                         0.021859
# 10                        -0.072734                        -0.081361
# 11                        -0.079680                        -0.059874
#
#     Cytoplasm_AreaShape_Zernike_2_0  Cytoplasm_AreaShape_Zernike_2_2  ...  \
# 0                         -0.034624                        -0.015618  ...
# 1                          0.008824                         0.012460  ...
# 2                         -0.005720                        -0.019584  ...
# 4                         -0.037867                         0.036271  ...
# 6                          0.004174                        -0.023955  ...
# 8                          0.054012                        -0.048090  ...
# 9                         -0.007972                         0.019015  ...
# 10                         0.036256                        -0.009928  ...
# 11                         0.012565                         0.000216  ...
#
#     uPA [NSU]  VCAM-1 [NSU]  VEGF Receptor 2 (Flk-1) [NSU]  \
# 0    0.469875      0.395392                       0.560129
# 1    0.493033      0.171562                       0.615867
# 2    0.570146      0.032391                       0.476656
# 4    0.374554      0.486915                       0.389375
# 6    0.428286      0.288884                       0.527908
# 8    0.630644      0.586271                       0.258029
# 9    0.462850      0.490826                       0.466632
# 10   0.315633      0.364173                       0.607592
# 11   0.527316      0.405934                       0.619578
#
#     VEGF-A (165) [NSU]  VEGF-C [NSU]  VEGF-D [NSU]  VEGFR-1 [NSU]  \
# 0             0.504521      0.490444      0.258834       0.238358
# 1             0.288153      0.506528      0.264141       0.296782
# 2             0.315426      0.589522      0.381170       0.168645
# 4             0.369421      0.680276      0.182956       0.263281
# 6             0.210755      0.448465      0.422773       0.535603
# 8             0.561051      0.551671      0.582053       0.087565
# 9             0.635065      0.333763      0.440537       0.218204
# 10            0.176816      0.378920      0.310344       0.651217
# 11            0.329964      0.577830      0.000000       0.456104
#
#     WISP-1 (CCN4) [NSU]  XCL1 (Lymphotactin) [NSU]  \
# 0              0.524276                   0.250670
# 1              0.541689                   0.167078
# 2              0.455092                   0.228752
# 4              0.213596                   0.064645
# 6              0.209011                   0.170498
# 8              0.140992                   0.234191
# 9              0.341123                   0.263401
# 10             0.679571                   0.222324
# 11             0.255216                   0.255703
#
#     fourb_Metadata_Treatment_Dose_Inhibitor_Dose_y
# 0                         DMSO__0.100__DMSO__0.025
# 1                         DMSO__0.100__DMSO__0.025
# 2                         DMSO__0.100__DMSO__0.025
# 4                         DMSO__0.100__DMSO__0.025
# 6                        LPS__100.000__DMSO__0.025
# 8                         DMSO__0.100__DMSO__0.025
# 9                         DMSO__0.100__DMSO__0.025
# 10                       LPS__100.000__DMSO__0.025
# 11                       LPS__100.000__DMSO__0.025
#
# [9 rows x 1458 columns]

# %%
# at random downsample the DMSO treatment to match the number of wells in the LPS treatment
seed = 0
# get the number of wells in the LPS treatment
trt_wells = training_data[
    training_data["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"] == treatment
].shape[0]
# get the number of wells in the DMSO treatment
dmso_wells = training_data[
    training_data["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"] == control
].shape[0]
# downsample the DMSO treatment to match the number of wells in the LPS treatment
dmso_holdout = training_data[
    training_data["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"] == control
].sample(n=trt_wells, random_state=seed)
# remove the downsampled DMSO wells from the data
training_data = training_data.drop(dmso_holdout.index)

# %%
# define metadata columns
# subset each column that contains metadata
metadata = training_data.filter(regex="Metadata")
# drop all metadata columns
data_x = training_data.drop(metadata.columns, axis=1)
labeled_data = training_data["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"]
# get all columns that contain "NSU" in the column name
data_y_cols = data_x.filter(regex="NSU").columns
data_y = training_data[data_y_cols]
data_x = data_x.drop(data_y_cols, axis=1)

# %%
for col in data_y.columns:
    train_y = data_y[col]
    shuffles = ["final", "shuffled_baseline"]
    feature_types = ["CP"]
    # create stratified data sets for continuous labels

    model = ElasticNetCV(
        random_state=0,
        max_iter=10000,
        cv=5,
        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.99],
        alphas=[0.01, 0.1, 1, 10, 100],
    )
    # train model on training data on all combinations of model types, feature types, and phenotypic classes
    for shuffle, feature_type in itertools.product(shuffles, feature_types):
        if shuffle == "shuffled_baseline":
            print("Shuffling data")
            for column in data_x:
                np.random.shuffle(data_x[column].values)
        else:
            print("Not shuffling data")
        # define parameters to search over
        with parallel_backend("multiprocessing"):
            with warnings.catch_warnings():
                warnings.filterwarnings(
                    "ignore", category=ConvergenceWarning, module="sklearn"
                )
                # create a logistic regression model

                model.fit(data_x, train_y)
        # print(f"Best alpha: {regression_model_params.alpha_}\n Best l1_ratio: {regression_model_params.l1_ratio_}")
        score = model.score(data_x, train_y)
        print("Fold score:", score)
        preds = model.predict(data_x)
        print(f"RMSE: {np.sqrt(mean_squared_error(train_y, preds))}")

        if (aggregation == True) and (nomic == True):
            results_dir = f"./models/single_class/{cell_type}/aggregated_with_nomic/{MODEL_TYPE}/{control}__{treatment}"
        elif (aggregation == True) and (nomic == False):
            results_dir = f"./models/single_class/{cell_type}/aggregated/{MODEL_TYPE}/{control}__{treatment}"
        elif (aggregation == False) and (nomic == True):
            results_dir = f"./models/single_class/{cell_type}/sc_with_nomic/{MODEL_TYPE}/{control}__{treatment}"
        elif (aggregation == False) and (nomic == False):
            results_dir = f"./models/single_class/{cell_type}/sc/{MODEL_TYPE}/{control}__{treatment}"
        else:
            print("Error")

        # create results directory if it doesn't exist
        pathlib.Path(results_dir).mkdir(parents=True, exist_ok=True)

        # print(f'Features: {model.feature_names_in_}')
        print(f"There were {len(model.feature_names_in_)} features selected")

        # save final estimator
        dump(
            model,
            f"{results_dir}/{shuffle}__{feature_type}_{col}.joblib",
        )

        # save condfig copy specific to this model to the folder with the results
        # use pathlib
        config_copy_path = pathlib.Path(
            f"{results_dir}/{shuffle}__{feature_type}_{col}.toml"
        )
        # write toml file with parameters used from injected parameters
        with open(config_copy_path, "a") as f:
            f.write(f"model_type='{shuffle}'\n")
            f.write(f"control='{control}'\n")
            f.write(f"treatments='{treatment}'\n")
            f.write(f"aggregation={aggregation}\n")
            f.write(f"nomic={nomic}\n")
            f.write(f"cell_type='{cell_type}'\n")
            f.write(f"feature='{col}'\n")
# Out:
# Not shuffling data
# Fold score: 0.9778199942451861
# RMSE: 0.05043208055555217
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.33863048913519683
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.66941055257008
# RMSE: 0.09761220424291997
# There were 1245 features selected
# Shuffling data
# Fold score: 0.8774319638993979
# RMSE: 0.059435817486629045
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9617070938342034
# RMSE: 0.059547778385193
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9981775332278393
# RMSE: 0.012990809345816987
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.083453242518188
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.083453242518188
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9955887020951646
# RMSE: 0.01107562868422846
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.16675743008919328
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9975655885296982
# RMSE: 0.01286788630294369
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.26080158239831197
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.900148346778821
# RMSE: 0.039912172404708374
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9002535623842874
# RMSE: 0.039891138750905504
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.7517082154994099
# RMSE: 0.04529145017700193
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.09089396559292645
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9892840509964271
# RMSE: 0.00927486084306858
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.08959671425490952
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.044855388164907244
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.044855388164907244
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.060858425211415684
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9844386363993972
# RMSE: 0.007591796102099741
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.12854471287895647
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9947692063754126
# RMSE: 0.009296896828117181
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.11774152881368397
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.11774152881368397
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.11072375680344837
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.11072375680344837
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.04049626223910663
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9642321379191503
# RMSE: 0.00765881239154056
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9885054219962994
# RMSE: 0.009369086745818586
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9105643929615965
# RMSE: 0.026134005226781568
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.02556070018775978
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9195180813899767
# RMSE: 0.007251400744610803
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.08284334372776699
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.08284334372776699
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.021327684959769836
# There were 1245 features selected
# Shuffling data
# Fold score: 0.8928335584084828
# RMSE: 0.006981891928805025
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.929425733441632
# RMSE: 0.02201260167785397
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.08286062185774154
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.1604171984223739
# There were 1245 features selected
# Shuffling data
# Fold score: 0.8896512419879439
# RMSE: 0.05328864191073253
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9851788968529762
# RMSE: 0.03954267408316189
# There were 1245 features selected
# Shuffling data
# Fold score: 0.1129378173379314
# RMSE: 0.3059164301913106
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.05070860478884284
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9729098226702537
# RMSE: 0.008346176897423315
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9379962257384356
# RMSE: 0.03933605668433224
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9950813714839639
# RMSE: 0.011079081816286232
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.8078927030785645
# RMSE: 0.06525097332978055
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.14887269957216295
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.12950919565324626
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9920923140200044
# RMSE: 0.011516627327751027
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9812852826891256
# RMSE: 0.03723278969784451
# There were 1245 features selected
# Shuffling data
# Fold score: 0.997307285140331
# RMSE: 0.014123070437017032
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.7618520831938822
# RMSE: 0.03975627638934358
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9917224180244866
# RMSE: 0.007411976828637294
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.07276307092375739
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9853232182914036
# RMSE: 0.008815083640408573
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9885241010490727
# RMSE: 0.009327048179806346
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.08706645506893428
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.5393389977143936
# RMSE: 0.07862966877409196
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9647592083517285
# RMSE: 0.021747961226181837
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.16960130974953788
# There were 1245 features selected
# Shuffling data
# Fold score: 0.734113986142011
# RMSE: 0.08745345029913197
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9910356652385368
# RMSE: 0.007395829125441274
# There were 1245 features selected
# Shuffling data
# Fold score: 0.29410296186499085
# RMSE: 0.06562941230031637
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9215240750386223
# RMSE: 0.03792680159759024
# There were 1245 features selected
# Shuffling data
# Fold score: 0.953675443282461
# RMSE: 0.029139603245842614
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.8842094417592816
# RMSE: 0.027506872764898986
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.08083596826593208
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9918542911828715
# RMSE: 0.00733710146288516
# There were 1245 features selected
# Shuffling data
# Fold score: 0.7506826811031604
# RMSE: 0.04059161288734879
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.03708150534315871
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.03708150534315871
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9946758541238325
# RMSE: 0.011783788652118947
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9955874384502373
# RMSE: 0.010727668869063416
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.4415260236854458
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9734766109474404
# RMSE: 0.07190694103071966
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9933666241854544
# RMSE: 0.010694574000120182
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.1313095123225332
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.2553231943528054
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9725113787310438
# RMSE: 0.0423318012205766
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.09143806564868526
# There were 1245 features selected
# Shuffling data
# Fold score: 0.8849102795325356
# RMSE: 0.031020250294577927
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.09816310067930396
# There were 1245 features selected
# Shuffling data
# Fold score: 0.7712289590443219
# RMSE: 0.04695142654547662
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.16350661520951063
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.16350661520951063
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9842349949994782
# RMSE: 0.008967054473266244
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9880889375525017
# RMSE: 0.007794315879015737
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.09004203260852174
# There were 1245 features selected
# Shuffling data
# Fold score: 0.6360124203229347
# RMSE: 0.05432360371878427
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9963360560321699
# RMSE: 0.012051369418893506
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.19909574917792705
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.10236008803383531
# There were 1245 features selected
# Shuffling data
# Fold score: 0.8086319058767644
# RMSE: 0.04477807470501278
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9915604223606471
# RMSE: 0.00865257620915868
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.09418572317354706
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.12963056251219804
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9342795145574204
# RMSE: 0.033232100067674845
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.14030919548434465
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.14030919548434465
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.096540671996098
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.096540671996098
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.0
# RMSE: 0.1824917795491934
# There were 1245 features selected
# Shuffling data
# Fold score: 0.9700563108629261
# RMSE: 0.031578824445624175
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.7336645281356047
# RMSE: 0.0993553582741387
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.1925204144209935
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.7301201437601685
# RMSE: 0.1015229074708366
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.19542441103522085
# There were 1245 features selected
# Not shuffling data
# Fold score: 0.9864348665749764
# RMSE: 0.00774448854025341
# There were 1245 features selected
# Shuffling data
# Fold score: 0.0
# RMSE: 0.06649373167874052
# There were 1245 features selected
