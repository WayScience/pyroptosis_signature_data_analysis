# %%
library(ggplot2)
library(corrplot)
library(dplyr)
library(reshape2)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘corrplot’ was built under R version 4.2.3”
# corrplot 0.92 loaded
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘reshape2’ was built under R version 4.2.3”

# %%
# load in the correct data set
data <- read.csv("/home/lippincm/Documents/ML/Interstellar_Analysis/1.Exploratory_Data_Analysis/SHSY5Y_B13_correlation_matrix.csv")

# %%
# remove the first column
data <- data[,-1]
head(data,2)
# Out:
#   feature                          Activin.A..NSU. AITRL..GITR.Ligand...NSU.
# 1 Cytoplasm_AreaShape_Compactness  0.06350389      -0.07218558
# 2 Cytoplasm_AreaShape_Eccentricity 0.01052847       0.03312459
#   Amphiregulin..NSU. Amyloid.beta..NSU. APRIL..NSU.  BAFF..NSU.
# 1 0.02213564         -0.06321751         0.039965342 -0.06950639
# 2 0.13264235          0.11033926        -0.007968936  0.05057428
#   BCMA..TNFRSF17...NSU. BDNF..NSU.    BMP2..NSU.  ⋯ TWEAK..NSU. uPA..NSU.
# 1  0.14773889           -0.0001838997  0.11536584 ⋯ -0.07272805  0.07586831
# 2 -0.02009566            0.0718867290 -0.03520659 ⋯  0.08202134 -0.26803038
#   VCAM.1..NSU. VEGF.Receptor.2..Flk.1...NSU. VEGF.A..165...NSU. VEGF.C..NSU.
# 1  0.11930834  -0.04639780                    0.2357834         0.08823268
# 2 -0.01254136   0.02721385                   -0.1341112         0.03720465
#   VEGF.D..NSU. VEGFR.1..NSU. WISP.1..CCN4...NSU. XCL1..Lymphotactin...NSU.
# ...

# %%
data <- melt(data)
# Out:
# Using feature as id variables

# %%
head(data,2)
# Out:
#   feature                          variable        value
# 1 Cytoplasm_AreaShape_Compactness  Activin.A..NSU. 0.06350389
# 2 Cytoplasm_AreaShape_Eccentricity Activin.A..NSU. 0.01052847

# %%
ggplot(data, aes(x=variable, y=feature, fill=value)) + 
  geom_tile() + 
  scale_fill_gradient(low="white", high="steelblue") +
  theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
  labs(x = "Gene", y = "Gene", title = "Correlation Matrix of SHSY5Y B13 Genes")
# Out:
# plot without title
