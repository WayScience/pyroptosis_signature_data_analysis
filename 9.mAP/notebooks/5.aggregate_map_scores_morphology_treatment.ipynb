# %%
import pathlib
import warnings

import numpy as np
import pandas as pd
import plotly.express as px
from copairs.map import aggregate

warnings.filterwarnings("ignore")

# %%
# Directories
processed_data_dir = pathlib.Path("../data/processed/")
sc_ap_scores_dir = (processed_data_dir / "mAP_scores/morphology").resolve()
agg_sc_ap_scores_dir = (processed_data_dir / "aggregate_mAPs/morphology").resolve()
agg_sc_ap_scores_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Preparing the dataset

# %%
all_files = list(sc_ap_scores_dir.glob("*.csv"))
# get the files that contain the string class
class_files = [file for file in all_files if "treatment" in file.stem]
mAPs = []
for file in class_files:
    df = pd.read_csv(file)
    df["file"] = file.stem
    mAPs.append(df)
# single-cell mAP scores
mAPs = pd.concat(mAPs)
mAPs.head()
# Out:
#   Metadata_Well        oneb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 0           B02                 Thapsigargin_1.000_uM_DMSO_0.025_%
# 1           B03                 LPS_100.000_ug_per_ml_DMSO_0.025_%
# 2           B04                                              Media
# 3           B05                  DMSO_0.100_%_Z-VAD-FMK_100.000_uM
# 4           B06  LPS_Nigericin_100.000_ug_per_ml_10.000_uM_DMSO...
#
#   Metadata_labels  average_precision  p_value  n_pos_pairs  n_total_pairs  \
# 0      Pyroptosis           0.021463      0.8            3            153
# 1      Pyroptosis           0.053956      0.4            3            153
# 2      Pyroptosis           0.043059      0.8            5            153
# 3      Pyroptosis           0.138639      0.2            3            153
# 4         Control           0.039502      0.4            3            153
#
#              shuffled                                 file
# 0  phenotype_shuffled  mAP_scores_shuffled_class_treatment
# 1  phenotype_shuffled  mAP_scores_shuffled_class_treatment
# 2  phenotype_shuffled  mAP_scores_shuffled_class_treatment
# 3  phenotype_shuffled  mAP_scores_shuffled_class_treatment
# 4  phenotype_shuffled  mAP_scores_shuffled_class_treatment

# %%
# grabbing all cp features (regular, feature shuffled and labeled shuffled)
reg_sc_mAPs = mAPs.loc[mAPs["shuffled"] == "non-shuffled"]
shuffled_feat_sc_mAPs = mAPs.loc[mAPs["shuffled"] == "features_shuffled"]
shuffled_pheno_sc_mAPs = mAPs.loc[mAPs["shuffled"] == "phenotype_shuffled"]

# %%
reg_sc_mAPs
# Out:
#     Metadata_Well        oneb_Metadata_Treatment_Dose_Inhibitor_Dose  \
# 0             B02                   LPS_0.010_ug_per_ml_DMSO_0.025_%
# 1             B03                   LPS_0.010_ug_per_ml_DMSO_0.025_%
# 2             B04  LPS_Nigericin_100.000_ug_per_ml_1.000_uM_DMSO_...
# 3             B05  LPS_Nigericin_100.000_ug_per_ml_1.000_uM_DMSO_...
# 4             B06                          DMSO_0.100_%_DMSO_0.025_%
# ..            ...                                                ...
# 149           O08  LPS_Nigericin_1.000_ug_per_ml_10.000_uM_Z-VAD-...
# 150           O09  LPS_Nigericin_1.000_ug_per_ml_10.000_uM_Z-VAD-...
# 151           O10                                              Media
# 152           O11                                              Media
# 153           O12                          DMSO_0.100_%_DMSO_1.000_%
#
#     Metadata_labels  average_precision  p_value  n_pos_pairs  n_total_pairs  \
# 0        Pyroptosis           0.072612      0.2            3            153
# 1        Pyroptosis           0.063540      0.2            3            153
# 2        Pyroptosis           0.497076      0.2            3            153
# 3        Pyroptosis           1.000000      0.2            3            153
# 4           Control           0.045209      1.0            7            153
# ..              ...                ...      ...          ...            ...
# 149         Control           0.809524      0.2            3            153
# 150         Control           0.208824      0.2            3            153
# 151         Control           0.439959      0.2            5            153
# 152         Control           0.449947      0.2            5            153
# 153         Control           0.866667      0.2            3            153
#
#          shuffled                          file
# 0    non-shuffled  mAP_scores_regular_treatment
# 1    non-shuffled  mAP_scores_regular_treatment
# 2    non-shuffled  mAP_scores_regular_treatment
# 3    non-shuffled  mAP_scores_regular_treatment
# 4    non-shuffled  mAP_scores_regular_treatment
# ..            ...                           ...
# 149  non-shuffled  mAP_scores_regular_treatment
# 150  non-shuffled  mAP_scores_regular_treatment
# 151  non-shuffled  mAP_scores_regular_treatment
# 152  non-shuffled  mAP_scores_regular_treatment
# 153  non-shuffled  mAP_scores_regular_treatment
#
# [154 rows x 9 columns]

# %%
# Generating sampling_error df
# This table will be used to merge with the aggregate table to get the sampling error a specific category.
merged_sc_ap_scores_df = pd.concat(
    [
        reg_sc_mAPs,
        shuffled_feat_sc_mAPs,
        shuffled_pheno_sc_mAPs,
    ]
)

# grouping dataframe based on phenotype levels, feature and feature types
df_group = merged_sc_ap_scores_df.groupby(
    by=["oneb_Metadata_Treatment_Dose_Inhibitor_Dose", "shuffled"]
)

# calculating sampling error
sampling_error_df = []
for name, df in df_group:
    pheno, shuffled_type = name

    # caclulating sampling error
    avg_percision = df["average_precision"].values
    sampling_error = np.std(avg_percision) / np.sqrt(len(avg_percision))

    sampling_error_df.append([pheno, shuffled_type, sampling_error])
cols = ["oneb_Metadata_Treatment_Dose_Inhibitor_Dose", "shuffled", "sampling_error"]
sampling_error_df = pd.DataFrame(sampling_error_df, columns=cols)

# updating name:
sampling_error_df.loc[
    sampling_error_df["shuffled"] == "phenotype_shuffled"
] = "phenotypes_shuffled"

sampling_error_df.head()
# Out:
#   oneb_Metadata_Treatment_Dose_Inhibitor_Dose             shuffled  \
# 0                   DMSO_0.100_%_DMSO_0.025_%    features_shuffled
# 1                   DMSO_0.100_%_DMSO_0.025_%         non-shuffled
# 2                         phenotypes_shuffled  phenotypes_shuffled
# 3                   DMSO_0.100_%_DMSO_1.000_%    features_shuffled
# 4                   DMSO_0.100_%_DMSO_1.000_%         non-shuffled
#
#         sampling_error
# 0              0.02047
# 1             0.009434
# 2  phenotypes_shuffled
# 3             0.005447
# 4             0.043139

# %%
# aggregate single cells scores with cell labels
data = tuple(
    merged_sc_ap_scores_df.groupby(by=["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"])
)
columns = merged_sc_ap_scores_df.columns
agg_sc_ap_scores_df = []
for cell_id, df1 in data:
    for shuffle_type, df2 in df1.groupby(by="shuffled"):
        aggregated_ap_score = df2["average_precision"].mean()

        # select a single row since all the metadata is the same
        selected_row = df2.iloc[0]

        # update the average precision score of the single row
        selected_row["average_precision"] = aggregated_ap_score
        agg_sc_ap_scores_df.append(selected_row.values.tolist())

# saving into the results repo
agg_sc_ap_scores_df = pd.DataFrame(data=agg_sc_ap_scores_df, columns=columns)
agg_sc_ap_scores_df.to_csv(
    sc_ap_scores_dir / "merged_sc_agg_ap_scores_treatment.csv", index=False
)
agg_sc_ap_scores_df.head()
# Out:
#   Metadata_Well oneb_Metadata_Treatment_Dose_Inhibitor_Dose Metadata_labels  \
# 0           D10                   DMSO_0.100_%_DMSO_0.025_%      Pyroptosis
# 1           B06                   DMSO_0.100_%_DMSO_0.025_%         Control
# 2           D10                   DMSO_0.100_%_DMSO_0.025_%      Pyroptosis
# 3           H05                   DMSO_0.100_%_DMSO_1.000_%         Control
# 4           C12                   DMSO_0.100_%_DMSO_1.000_%         Control
#
#    average_precision  p_value  n_pos_pairs  n_total_pairs            shuffled  \
# 0           0.077559      1.0            7            153   features_shuffled
# 1           0.059431      1.0            7            153        non-shuffled
# 2           0.119956      1.0            7            153  phenotype_shuffled
# 3           0.033508      0.8            3            153   features_shuffled
# 4           0.798611      0.2            3            153        non-shuffled
#
#                                           file
# 0  mAP_scores_shuffled_feature_space_treatment
# 1                 mAP_scores_regular_treatment
# 2          mAP_scores_shuffled_class_treatment
# 3  mAP_scores_shuffled_feature_space_treatment
# 4                 mAP_scores_regular_treatment

# %%
# Generating aggregate scores with a threshold p-value of 0.05
mAP_dfs = []
for name, df in tuple(
    agg_sc_ap_scores_df.groupby(
        by=["oneb_Metadata_Treatment_Dose_Inhibitor_Dose", "shuffled"]
    )
):
    agg_df = aggregate(
        df, sameby=["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"], threshold=0.05
    )
    agg_df["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"] = name[0]
    agg_df["shuffled"] = name[1]
    mAP_dfs.append(agg_df)

mAP_dfs = pd.concat(mAP_dfs)
mAP_dfs.to_csv(agg_sc_ap_scores_dir / "mAP_scores_treatment.csv", index=False)
mAP_dfs.head()
# Out:
#   oneb_Metadata_Treatment_Dose_Inhibitor_Dose  mean_average_precision  \
# 0                   DMSO_0.100_%_DMSO_0.025_%                0.077559
# 0                   DMSO_0.100_%_DMSO_0.025_%                0.059431
# 0                   DMSO_0.100_%_DMSO_0.025_%                0.119956
# 0                   DMSO_0.100_%_DMSO_1.000_%                0.033508
# 0                   DMSO_0.100_%_DMSO_1.000_%                0.798611
#
#    nlog10pvalue  q_value  nlog10qvalue  above_p_threshold  above_q_threshold  \
# 0      -0.00000      1.0      -0.00000              False              False
# 0      -0.00000      1.0      -0.00000              False              False
# 0      -0.00000      1.0      -0.00000              False              False
# 0       0.09691      0.8       0.09691              False              False
# 0       0.69897      0.2       0.69897              False              False
#
#              shuffled
# 0   features_shuffled
# 0        non-shuffled
# 0  phenotype_shuffled
# 0   features_shuffled
# 0        non-shuffled

# %% [markdown]
# ## Forming bar plots

# %% [markdown]
# ### Forming bar plots with CP Features

# %%
# selecting dataset to plot
agg_reg_sc_mAPs = mAP_dfs.loc[(mAP_dfs["shuffled"] == "non-shuffled")]
agg_shuffled_feat_sc_mAPs = mAP_dfs.loc[(mAP_dfs["shuffled"] == "features_shuffled")]
agg_shuffled_pheno_sc_mAPs = mAP_dfs.loc[(mAP_dfs["shuffled"] == "phenotype_shuffled")]

# phenotypes
df = (
    pd.concat(
        [
            agg_reg_sc_mAPs,
            agg_shuffled_feat_sc_mAPs,
            agg_shuffled_pheno_sc_mAPs,
        ]
    )
    .reset_index()
    .drop("index", axis=1)
)[["oneb_Metadata_Treatment_Dose_Inhibitor_Dose", "mean_average_precision", "shuffled"]]


fig = px.bar(
    df,
    x="oneb_Metadata_Treatment_Dose_Inhibitor_Dose",
    y="mean_average_precision",
    color="shuffled",
    barmode="group",
    title="Mean Average Precision for each Cell Death Phenotype",
    labels={
        "mean_average_precision": "Mean Average Precision",
        "oneb_Metadata_Treatment_Dose_Inhibitor_Dose": "Cell Death Phenotypes",
    },
)

# %% [markdown]
# ## Generating box plots of single cell ap scores

# %%
all_df = pd.concat(
    [
        reg_sc_mAPs,
        shuffled_feat_sc_mAPs,
        shuffled_pheno_sc_mAPs,
    ]
)

# %%
# Assuming all_cp_df, all_dp_df, and all_cp_dp_df are your DataFrames
categories_order = all_df["oneb_Metadata_Treatment_Dose_Inhibitor_Dose"].unique()

# Create individual figures with the same category order
fig1 = px.box(
    all_df,
    x="oneb_Metadata_Treatment_Dose_Inhibitor_Dose",
    y="average_precision",
    color="shuffled",
    title="Single Well Average Percision Scores",
    category_orders={"oneb_Metadata_Treatment_Dose_Inhibitor_Dose": categories_order},
    labels={
        "average_precision": "Average Precision Scores",
        "oneb_Metadata_Treatment_Dose_Inhibitor_Dose": "Treatment",
    },
)
